# %% [markdown]
# # Studying the effects of the energy resolution

# %% [markdown]
# Miscellaneous:

# %%
import sys

sys.path.append("../../..")

import numpy as np
import pandas as pd
from scipy import optimize
import matplotlib.pyplot as plt
from matplotlib import rc
import mpl_toolkits.axes_grid1.inset_locator as inloc
import scipy.stats as stats
import src.energy_effects_t2k.convolution as conv
import src.nu_osc.osc_prob as osc
import src.nu_osc.default_parameters as param

# %% [markdown]
# <p> </p>
# To make plots more beautiful

# %%
rc("figure", figsize=(10, 5))
# rc('lines', linewidth=2)
rc("axes", labelsize=12, linewidth=1, grid=True, labelpad=-1, axisbelow=True)
rc("axes.spines", right=True)
rc("xtick", direction="in", labelsize=12, top=True)
rc("xtick.major", width=0.8, size=5)
rc("ytick", direction="in", labelsize=12, right=True)
rc("ytick.major", width=0.8, size=5)
rc("legend", fancybox=False, fontsize=12, shadow=False)
rc(
    "grid",
    linewidth=1.0,
)  # ls='dotted')
# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('retina')

# %%
colors = {
    "numu": "darkgreen",
    "antinumu": "darkseagreen",
    "nue": "red",
    "antinue": "rosybrown",
    "nutau": "teal",
    "antinutau": "cadetblue",
}

# %% [markdown]
# ## Plotting the best fit from NuFIT 2024

# %% [markdown]
# Importing the T2K FHC flux:

# %%
t2kflux_2020_minus250kA_nominal_sk = conv.fluximport(
    "t2kflux_2020_minus250kA_nominal_sk.csv"
)

# %% [markdown]
# Importing the neutrino CCQE interaction cross-section:

# %%
ccqe_interp = conv.xsecimport(
    name="neutrino_ccqe.csv",
    mode="true filter interp",
    keep_left=5,
    on=(
        t2kflux_2020_minus250kA_nominal_sk.minE
        + t2kflux_2020_minus250kA_nominal_sk.maxE
    )
    / 2,
)

# %% [markdown]
# Multiplying the flux, the cross-section and SK's sp to obtain the numbers per MeV at SK:

# %%
number = pd.DataFrame()
for key in ["minE", "maxE"]:
    number[key] = t2kflux_2020_minus250kA_nominal_sk[key]
for key in ["numu", "antinumu", "nue", "antinue"]:
    number[key] = (
        ccqe_interp.xsec
        * t2kflux_2020_minus250kA_nominal_sk[key]
        / (50 * 1e21)
        # * param.SK_POT["RHC"]
        # * param.TOT_NEUTRONS
        # * 2
    )

# %% [markdown]
# Oscillating the number with the best fit from NuFIT 24:

# %%
number["nue"] = 0.0
number["antinue"] = 0.0
number["nutau"] = 0.0
number["antinutau"] = 0.0

# %%
number_oscillated = {
    "bf": conv.oscillate(to_oscillate=number),
    "p1sigma": conv.oscillate(
        to_oscillate=number, dm2_atm=param.NUFIT["Dm_square_32"]["p1sigma"]
    ),
    "m1sigma": conv.oscillate(
        to_oscillate=number, dm2_atm=param.NUFIT["Dm_square_32"]["m1sigma"]
    ),
    "p3sigma": conv.oscillate(
        to_oscillate=number, dm2_atm=param.NUFIT["Dm_square_32"]["p3sigma"]
    ),
    "m3sigma": conv.oscillate(
        to_oscillate=number, dm2_atm=param.NUFIT["Dm_square_32"]["m3sigma"]
    ),
}

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 10), sharex="col", sharey="col")

for i in [0, 1]:
    for key in [
        "numu",
        "nue",
        "antinumu",
        "antinue",
    ]:  # "nutau", "antinutau"]:
        axs[0, i].step(
            number.minE,
            number[key],
            label=conv.print_dict[key],
            color=colors[key],
            where="post",
        )

        axs[1, i].step(
            number_oscillated["bf"].minE,
            number_oscillated["bf"][key],
            label=conv.print_dict[key] + r" ($\times \mathcal{P}$)",
            color=colors[key],
            where="post",
        )

    axs[1, i].set_xlabel(r"$E$ [GeV]")

for ax in axs.reshape(-1):
    ax.set_xscale("log")
    ax.legend()
    ax.text(
        x=0.6,
        y=0.5,
        s=r"600 MeV",
        ha="right",
        va="top",
        rotation=90,
        transform=ax.get_xaxis_transform(),
    )
    ax.axvline(x=0.6, linestyle="--", color="black")

for i in range(2):
    axs[i, 0].set_yscale("log")
    # axs[i,0].set_ylim(bottom=1e-1)
    axs[i, 1].yaxis.tick_right()

axs[0, 0].set_ylabel(r"Number per energy bin [$\text{MeV}^{-1}$]")
axs[1, 0].set_ylabel(r"Number per energy bin [$\text{MeV}^{-1}$]")

fig.suptitle(
    r"[(T2K Flux 2020 | Nominal conditions | SK | $-250$ kA) $\ \times \ $ (CCQE only)] $\ \ \times \ \ $ (Oscillation probability | ME | NO)",
    fontsize=15,
)
fig.tight_layout()

plt.show()

# %%
rc("figure", figsize=(10, 6))
for key in [
    "numu",
    "nue",
    "antinumu",
    "antinue",
]:  # "nutau", "antinutau"]:

    plt.step(
        number_oscillated["bf"].minE,
        number_oscillated["bf"][key],
        label=conv.print_dict[key] + r" ($\times \mathcal{P}$)",
        color=colors[key],
        where="post",
    )


plt.axvline(x=0.6, linestyle="--", color="black")
ax = plt.gca()
plt.text(
    x=0.6,
    y=0.5,
    s=r"600 MeV",
    ha="right",
    va="top",
    rotation=90,
    transform=ax.get_xaxis_transform(),
)

plt.xlim(0.08, 11)
plt.xscale("log")
# plt.yscale("log")
plt.xlabel(r"$E$ [GeV]")
plt.ylabel(
    r"Number density [$\text{MeV}^{-1} \cdot \text{PoT}^{-1} \cdot \text{nucleon}^{-1}$]"
)
# plt.ylim(bottom=1e-1)
plt.title(
    r"Number of expected CCQE $\nu$ at SK in (RHC | Nominal) with NuFIT24 param. in (NO | ME)"
)
plt.legend()

plt.show()

# %%
(number_oscillated["bf"].antinumu * (number.maxE - number.minE) * 1e3).sum()
# Out:
# 9.200870466805952e-54

# %%
for key in ["antinumu"]:
    plt.plot(
        (number.minE + number.maxE) / 2,
        number[key],
        label=conv.print_dict[key],
        color=colors[key],
        # alpha=.5,
        # linestyle='--',
    )

    plt.plot(
        (number_oscillated["bf"].minE + number_oscillated["bf"].maxE) / 2,
        number_oscillated["bf"][key],
        label=conv.print_dict[key] + r" ($\times \mathcal{P}$) (BF)",
        color="indianred",
    )

    plt.fill_between(
        (number_oscillated["bf"].minE + number_oscillated["bf"].maxE) / 2,
        number_oscillated["m3sigma"][key],
        number_oscillated["p3sigma"][key],
        label=conv.print_dict[key]
        + r" ($\times \mathcal{P})\ (\Delta m_{32}^2 \pm 3\sigma$)",
        color="indianred",
        alpha=0.5,
    )


plt.axvline(x=0.6, linestyle="--", color="black")
ax = plt.gca()
plt.text(
    x=0.6,
    y=0.5,
    s=r"600 MeV",
    ha="right",
    va="top",
    rotation=90,
    transform=ax.get_xaxis_transform(),
)

# plt.xscale("log")
# plt.yscale("log")
plt.xlabel(r"$E$ [GeV]")
plt.ylabel(r"Number per energy bin [$\text{MeV}^{-1}$]")
# plt.ylim(bottom=1e-1)
plt.xlim([0.1, 1.25])
plt.title(
    r"Number of expected CCQE $\nu_\mu$ at SK in (RHC | Nominal) with NuFIT24 param. in (NO | ME)"
)
plt.legend()

plt.show()

# %%
ccqe_energy_res_interp = conv.energyimport(
    name="ccqe_energy_res.csv", mode="interp", on=np.linspace(-0.5, 1.0, 125)
)

# %%
oscillated_smeared = {}
for key in number_oscillated:
    oscillated_smeared[key] = conv.convolve(
        input=number_oscillated[key], gate=ccqe_energy_res_interp
    )

# %%
params = {
    "dm2_atm": [
        param.NUFIT["Dm_square_32"]["m3sigma"],
        param.NUFIT["Dm_square_32"]["p3sigma"],
    ]
}

number_oscillated["min"], number_oscillated["max"] = conv.envelope(
    to_oscillate=number, params=params, n=10
)
oscillated_smeared["min"], oscillated_smeared["max"] = conv.envelope(
    to_oscillate=number, params=params, gate=ccqe_energy_res_interp, n=10
)

# %%
conv.oscillated_plot(
    number_oscillated=number_oscillated,
    oscillated_smeared=oscillated_smeared,
    params=params,
    keys=["antinumu"],
    channel=r"$\overline{\nu}_\mu$",
    resolution="CCQE",
)
conv.oscillated_plot(
    number_oscillated=number_oscillated,
    oscillated_smeared=oscillated_smeared,
    params=params,
    keys=["antinue"],
    channel=r"$\overline{\nu}_e$",
    resolution="CCQE",
)

# %%
number_oscillated = {
    "bf": conv.oscillate(
        to_oscillate=number,
        delta_cp=3 * np.pi / 2,
    ),
    "p1sigma": conv.oscillate(to_oscillate=number, delta_cp=2 * np.pi),
    "m1sigma": conv.oscillate(to_oscillate=number, delta_cp=np.pi),
    "p3sigma": conv.oscillate(to_oscillate=number, delta_cp=2 * np.pi),
    "m3sigma": conv.oscillate(to_oscillate=number, delta_cp=np.pi),
}

oscillated_smeared = {}
for key in number_oscillated:
    oscillated_smeared[key] = conv.convolve(
        input=number_oscillated[key], gate=ccqe_energy_res_interp
    )

params = {"delta_cp": [np.pi, 2 * np.pi]}

number_oscillated["min"], number_oscillated["max"] = conv.envelope(
    to_oscillate=number, params=params
)
oscillated_smeared["min"], oscillated_smeared["max"] = conv.envelope(
    to_oscillate=number, params=params, gate=ccqe_energy_res_interp
)

# %%
conv.oscillated_plot(
    number_oscillated=number_oscillated,
    oscillated_smeared=oscillated_smeared,
    params=params,
    keys=["antinumu"],
    channel=r"$\overline{\nu}_\mu$",
    resolution="CCQE",
)
conv.oscillated_plot(
    number_oscillated=number_oscillated,
    oscillated_smeared=oscillated_smeared,
    params=params,
    keys=["antinue"],
    channel=r"$\overline{\nu}_\mu \to \overline{\nu}_e$",
    resolution="CCQE",
)

# %%
number_oscillated = {
    "bf": conv.oscillate(to_oscillate=number),
    "p1sigma": conv.oscillate(
        to_oscillate=number, theta_23=param.NUFIT["theta_23"]["p1sigma"]
    ),
    "m1sigma": conv.oscillate(
        to_oscillate=number, theta_23=param.NUFIT["theta_23"]["m1sigma"]
    ),
    "p3sigma": conv.oscillate(
        to_oscillate=number, theta_23=param.NUFIT["theta_23"]["p3sigma"]
    ),
    "m3sigma": conv.oscillate(
        to_oscillate=number, theta_23=param.NUFIT["theta_23"]["m3sigma"]
    ),
}

oscillated_smeared = {}
for key in number_oscillated:
    oscillated_smeared[key] = conv.convolve(
        input=number_oscillated[key], gate=ccqe_energy_res_interp
    )

params = {
    "theta_23": [param.NUFIT["theta_23"]["m3sigma"], param.NUFIT["theta_23"]["p3sigma"]]
}

number_oscillated["min"], number_oscillated["max"] = conv.envelope(
    to_oscillate=number, params=params
)
oscillated_smeared["min"], oscillated_smeared["max"] = conv.envelope(
    to_oscillate=number, params=params, gate=ccqe_energy_res_interp
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 27
#      19     oscillated_smeared[key] = conv.convolve(
#      20         input=number_oscillated[key], gate=ccqe_energy_res_interp
#      21     )
#      23 params = {
#      24     "theta_23": [param.NUFIT["theta_23"]["m3sigma"], param.NUFIT["theta_23"]["p3sigma"]]
#      25 }
# ---> 27 number_oscillated["min"], number_oscillated["max"] = conv.envelope(
#      28     to_oscillate=number, params=params
#      29 )
#      30 oscillated_smeared["min"], oscillated_smeared["max"] = conv.envelope(
#      31     to_oscillate=number, params=params, gate=ccqe_energy_res_interp
#      32 )
#
# File ~/Github/energy-effects-T2K/docs/source/notebooks/../../../src/energy_effects_t2k/convolution.py:404, in envelope(to_oscillate, params, gate, n)
#     402 m = len(params)
#     403 keys = np.linspace(0.0, n**m, n**m)
# --> 404 list_of_df = envelope_list(
#     405     to_oscillate=to_oscillate, vparams=params.copy(), gate=gate, n=n
#     406 )
#     407 oscillate_max = pd.concat(list_of_df, keys=keys).groupby(level=1).max()
#     408 oscillate_min = pd.concat(list_of_df, keys=keys).groupby(level=1).min()
#
# File ~/Github/energy-effects-T2K/docs/source/notebooks/../../../src/energy_effects_t2k/convolution.py:384, in envelope_list(to_oscillate, vparams, fparams, gate, n)
#     381 list_of_df = []
#     383 for value in sample:
# --> 384     list_of_df += envelope_list(
#     385         to_oscillate=to_oscillate,
#     386         vparams=vparams.copy(),
#     387         fparams=fparams | {key: value},
#     388         gate=gate,
#     389         n=n,
#     390     )
#     392 return list_of_df
#
# File ~/Github/energy-effects-T2K/docs/source/notebooks/../../../src/energy_effects_t2k/convolution.py:373, in envelope_list(to_oscillate, vparams, fparams, gate, n)
#     370     raise ValueError("Empty envelope.")
#     372 else:
# --> 373     oscillated = oscillate(to_oscillate=to_oscillate, **fparams)
#     374     if gate is not None:
#     375         oscillated = convolve(input=oscillated, gate=gate)
#
# File ~/Github/energy-effects-T2K/docs/source/notebooks/../../../src/energy_effects_t2k/convolution.py:314, in oscillate(to_oscillate, **osc_param)
#     307 oscillated.loc[i, "nue"] = (
#     308     to_oscillate.loc[i, "nue"] * Pee + to_oscillate.loc[i, "numu"] * Pme
#     309 )
#     310 oscillated.loc[i, "nutau"] = (
#     311     to_oscillate.loc[i, "nue"] * Pet + to_oscillate.loc[i, "numu"] * Pmt
#     312 )
# --> 314 Pee, Pem, Pet, Pme, Pmm, Pmt, Pte, Ptm, Ptt = osc.probability_general_anti(
#     315     E=(oscillated.maxE.loc[i] + oscillated.minE.loc[i]) / 2, **osc_param
#     316 )
#     317 oscillated.loc[i, "antinumu"] = (
#     318     to_oscillate.loc[i, "antinumu"] * Pmm + to_oscillate.loc[i, "antinue"] * Pem
#     319 )
#     320 oscillated.loc[i, "antinue"] = (
#     321     to_oscillate.loc[i, "antinue"] * Pee + to_oscillate.loc[i, "antinumu"] * Pme
#     322 )
#
# File ~/Github/energy-effects-T2K/docs/source/notebooks/../../../src/nu_osc/osc_prob.py:283, in probability_general_anti(E, theta_12, theta_13, theta_23, delta_cp, dm2_21, dm2_atm, compute_matrix_multiplication, L, ME, MO)
#     273 h_vacuum_energy_ind = hamiltonian_3nu_energy_independent(
#     274     theta_12,
#     275     theta_13,
#    (...)
#     280     compute_matrix_multiplication=True,
#     281 )
#     282 VCC_matrix = [[VCC, 0, 0], [0, 0, 0], [0, 0, 0]]
# --> 283 return probability_energy_fixed(
#     284     np.multiply(1.0 / E / 1.0e9, h_vacuum_energy_ind) + VCC_matrix,
#     285     L,
#     286 )
#
# File ~/Github/energy-effects-T2K/docs/source/notebooks/../../../src/nu_osc/hamiltonians.py:612, in probability_energy_fixed(hamiltonian_matrix, L)
#     579 def probability_energy_fixed(hamiltonian_matrix, L=BASELINE * CONV_KM_TO_INV_EV):
#     580     r"""Returns the 3nu oscillation probability.
#     581
#     582     Returns the three-neutrino oscillation probabilities
#    (...)
#     610     0.58145 0.174965
#     611     """
# --> 612     U = evolution_operator_3nu(hamiltonian_matrix, L)
#     614     Pee = abs(U[0][0]) ** 2.0
#     615     Pem = abs(U[1][0]) ** 2.0
#
# File ~/Github/energy-effects-T2K/docs/source/notebooks/../../../src/nu_osc/hamiltonians.py:566, in evolution_operator_3nu(hamiltonian_matrix, L)
#     533 def evolution_operator_3nu(hamiltonian_matrix, L):
#     534     r"""Returns the 3nu time-evolution operator in its SU(3) expanstion.
#     535
#     536     Returns the three-neutrino time-evolution operator U3(L) in its
#    (...)
#     564      [-0.170201+0.463257j -0.384525+0.65848j  -0.173265+0.380716j]]
#     565     """
# --> 566     u0, u1, u2, u3, u4, u5, u6, u7, u8 = evolution_operator_3nu_u_coefficients(
#     567         hamiltonian_matrix, L
#     568     )
#     570     evolution_operator = [
#     571         [u0 + 1.0j * (u3 + u8 / SQRT3), 1.0j * u1 + u2, 1.0j * u4 + u5],
#     572         [1.0j * u1 - u2, u0 - 1.0j * (u3 - u8 / SQRT3), 1.0j * u6 + u7],
#     573         [1.0j * u4 - u5, 1.0j * u6 - u7, u0 - 1.0j * 2.0 * u8 / SQRT3],
#     574     ]
#     576     return evolution_operator
#
# File ~/Github/energy-effects-T2K/docs/source/notebooks/../../../src/nu_osc/hamiltonians.py:512, in evolution_operator_3nu_u_coefficients(hamiltonian_matrix, L)
#     509 exp_psi = [cmath.exp(1.0j * L * x) for x in psi]
#     511 u0 = sum([x for x in exp_psi]) / 3.0
# --> 512 uk = [
#     513     1.0j
#     514     * sum(
#     515         [
#     516             exp_psi[m]
#     517             * (psi[m] * h_coeffs[k] - star(k, h_coeffs))
#     518             / (3.0 * psi[m] * psi[m] - h2)
#     519             for m in [0, 1, 2]
#     520         ]
#     521     )
#     522     for k in range(0, 8)
#     523 ]
#     525 # [u0, u1, u2, u3, u4, u5, u6, u7, u8]
#     526 u_coeffs = [u0] + uk
#
# File ~/Github/energy-effects-T2K/docs/source/notebooks/../../../src/nu_osc/hamiltonians.py:515, in <listcomp>(.0)
#     509 exp_psi = [cmath.exp(1.0j * L * x) for x in psi]
#     511 u0 = sum([x for x in exp_psi]) / 3.0
#     512 uk = [
#     513     1.0j
#     514     * sum(
# --> 515         [
#     516             exp_psi[m]
#     517             * (psi[m] * h_coeffs[k] - star(k, h_coeffs))
#     518             / (3.0 * psi[m] * psi[m] - h2)
#     519             for m in [0, 1, 2]
#     520         ]
#     521     )
#     522     for k in range(0, 8)
#     523 ]
#     525 # [u0, u1, u2, u3, u4, u5, u6, u7, u8]
#     526 u_coeffs = [u0] + uk
#
# File ~/Github/energy-effects-T2K/docs/source/notebooks/../../../src/nu_osc/hamiltonians.py:517, in <listcomp>(.0)
#     509 exp_psi = [cmath.exp(1.0j * L * x) for x in psi]
#     511 u0 = sum([x for x in exp_psi]) / 3.0
#     512 uk = [
#     513     1.0j
#     514     * sum(
#     515         [
#     516             exp_psi[m]
# --> 517             * (psi[m] * h_coeffs[k] - star(k, h_coeffs))
#     518             / (3.0 * psi[m] * psi[m] - h2)
#     519             for m in [0, 1, 2]
#     520         ]
#     521     )
#     522     for k in range(0, 8)
#     523 ]
#     525 # [u0, u1, u2, u3, u4, u5, u6, u7, u8]
#     526 u_coeffs = [u0] + uk
#
# File ~/Github/energy-effects-T2K/docs/source/notebooks/../../../src/nu_osc/hamiltonians.py:391, in star(i, h_coeffs)
#     373 def star(i, h_coeffs):
#     374     r"""Returns the SU(3) star oroduct (h*h)_i.
#     375
#     376     Returns the SU(3) star product (h*h)_i = d_ijk*h^j*h^k (summed over
#    (...)
#     389         Star product (h*h)_i.
#     390     """
# --> 391     res = sum(
#     392         [
#     393             tensor_d(i, j, k) * h_coeffs[j] * h_coeffs[k]
#     394             for j in range(0, 8)
#     395             for k in range(0, 8)
#     396         ]
#     397     )
#     399     return res
#
# File ~/Github/energy-effects-T2K/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File ~/Github/energy-effects-T2K/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
conv.oscillated_plot(
    number_oscillated=number_oscillated,
    oscillated_smeared=oscillated_smeared,
    params=params,
    keys=["antinumu"],
    channel=r"$\overline{\nu}_\mu$",
    resolution="CCQE",
)
conv.oscillated_plot(
    number_oscillated=number_oscillated,
    oscillated_smeared=oscillated_smeared,
    params=params,
    keys=["antinue"],
    channel=r"$\overline{\nu}_e$",
    resolution="CCQE",
)

# %%
number_oscillated = {
    "bf": conv.oscillate(to_oscillate=number),
    "p1sigma": conv.oscillate(
        to_oscillate=number,
        dm2_atm=param.NUFIT["Dm_square_32"]["p1sigma"],
        delta_cp=param.NUFIT["delta_CP"]["p1sigma"],
        theta_23=param.NUFIT["theta_23"]["p1sigma"],
    ),
    "m1sigma": conv.oscillate(
        to_oscillate=number,
        dm2_atm=param.NUFIT["Dm_square_32"]["m1sigma"],
        delta_cp=param.NUFIT["delta_CP"]["m1sigma"],
        theta_23=param.NUFIT["theta_23"]["m1sigma"],
    ),
    "p3sigma": conv.oscillate(
        to_oscillate=number,
        dm2_atm=param.NUFIT["Dm_square_32"]["p3sigma"],
        delta_cp=param.NUFIT["delta_CP"]["p3sigma"],
        theta_23=param.NUFIT["theta_23"]["p3sigma"],
    ),
    "m3sigma": conv.oscillate(
        to_oscillate=number,
        dm2_atm=param.NUFIT["Dm_square_32"]["m3sigma"],
        delta_cp=param.NUFIT["delta_CP"]["m3sigma"],
        theta_23=param.NUFIT["theta_23"]["m3sigma"],
    ),
}

oscillated_smeared = {}
for key in number_oscillated:
    oscillated_smeared[key] = conv.convolve(
        input=number_oscillated[key], gate=ccqe_energy_res_interp
    )

params = {
    "dm2_atm": [
        param.NUFIT["Dm_square_32"]["m3sigma"],
        param.NUFIT["Dm_square_32"]["p3sigma"],
    ],
    "delta_cp": [
        param.NUFIT["delta_CP"]["m3sigma"],
        param.NUFIT["delta_CP"]["p3sigma"],
    ],
    "theta_23": [
        param.NUFIT["theta_23"]["m3sigma"],
        param.NUFIT["theta_23"]["p3sigma"],
    ],
}

number_oscillated["min"], number_oscillated["max"] = conv.envelope(
    to_oscillate=number, params=params, n=5
)
oscillated_smeared["min"], oscillated_smeared["max"] = conv.envelope(
    to_oscillate=number, params=params, gate=ccqe_energy_res_interp, n=5
)

# %%
conv.oscillated_plot(
    number_oscillated=number_oscillated,
    oscillated_smeared=oscillated_smeared,
    params=params,
    keys=["antinumu"],
    channel=r"$\overline{\nu}_\mu$",
    resolution="CCQE",
)
conv.oscillated_plot(
    number_oscillated=number_oscillated,
    oscillated_smeared=oscillated_smeared,
    params=params,
    keys=["antinue"],
    channel=r"$\overline{\nu}_e$",
    resolution="CCQE",
)
